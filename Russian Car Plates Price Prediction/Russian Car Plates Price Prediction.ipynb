# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from supplemental_english import REGION_CODES, GOVERNMENT_CODES
import sys
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    id      plate                 date   price
# 0   1  X059CP797  2024-12-26 00:00:00   65000
# 1   2  Y800MH790  2024-07-12 21:31:37  100000
# 2   3   A212TX77  2024-04-18 00:00:00  290000
# 3   4  P001AY199  2025-01-03 00:27:15  680000
# 4   5  P001AY199  2025-01-10 09:32:41  750000

# %%
train.shape
# Out:
# (51635, 4)

# %%
train.isnull().sum()
# Out:
# id       0
# plate    0
# date     0
# price    0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#       id      plate                 date  price
# 0  51636  P700TT790  2025-01-27 00:00:00    NaN
# 1  51637  M081TX797  2025-02-10 00:00:00    NaN
# 2  51638  T333HX777  2025-02-11 00:00:00    NaN
# 3  51639  H744BH977  2025-02-03 00:00:00    NaN
# 4  51640  X066EM777  2025-02-12 00:00:00    NaN

# %%
test.shape
# Out:
# (7695, 4)

# %%
test.isnull().sum()
# Out:
# id          0
# plate       0
# date        0
# price    7695
# dtype: int64

# %%
test.duplicated().sum()
# Out:
# 0

# %%
file_path = os.path.abspath('supplemental_english.py') 
sys.path.append(file_path)

# %%
max_len = max(len(v) for v in REGION_CODES.values())

# %%
for k in REGION_CODES:
    while len(REGION_CODES[k]) < max_len:
        REGION_CODES[k].append(None)

# %%
region_codes_df = pd.DataFrame(REGION_CODES)
region_codes_df
# Out:
#   Republic of Adygea Altai Republic Republic of Bashkortostan  \
# 0                 01             04                        02
# 1               None           None                       102
# 2               None           None                       702
# 3               None           None                      None
# 4               None           None                      None
# 5               None           None                      None
# 6               None           None                      None
# 7               None           None                      None
# 8               None           None                      None
# 9               None           None                      None
#
#   Republic of Buryatia Republic of Dagestan Donetsk People's Republic  \
# 0                   03                   05                        80
# 1                 None                 None                       180
# 2                 None                 None                      None
# 3                 None                 None                      None
# 4                 None                 None                      None
# 5                 None                 None                      None
# 6                 None                 None                      None
# 7                 None                 None                      None
# 8                 None                 None                      None
# 9                 None                 None                      None
#
#   Republic of Ingushetia Kabardino-Balkarian Republic Republic of Kalmykia  \
# 0                     06                           07                   08
# 1                   None                         None                 None
# 2                   None                         None                 None
# 3                   None                         None                 None
# 4                   None                         None                 None
# 5                   None                         None                 None
# 6                   None                         None                 None
# 7                   None                         None                 None
# 8                   None                         None                 None
# 9                   None                         None                 None
#
#   Karachay-Cherkess Republic  ... Moscow Saint Petersburg Sevastopol  \
# 0                         09  ...     77               78         92
# 1                       None  ...     97               98       None
# 2                       None  ...     99              178       None
# 3                       None  ...    177              198       None
# 4                       None  ...    197             None       None
# 5                       None  ...    199             None       None
# 6                       None  ...    777             None       None
# 7                       None  ...    797             None       None
# 8                       None  ...    799             None       None
# 9                       None  ...    977             None       None
#
#   Jewish Autonomous Oblast Nenets Autonomous Okrug  \
# 0                       79                      83
# 1                     None                    None
# 2                     None                    None
# 3                     None                    None
# 4                     None                    None
# 5                     None                    None
# 6                     None                    None
# 7                     None                    None
# 8                     None                    None
# 9                     None                    None
#
#   Khanty-Mansi Autonomous Okrug Chukotka Autonomous Okrug  \
# 0                            86                        87
# 1                           186                      None
# 2                          None                      None
# 3                          None                      None
# 4                          None                      None
# 5                          None                      None
# 6                          None                      None
# 7                          None                      None
# 8                          None                      None
# 9                          None                      None
#
#   Yamalo-Nenets Autonomous Okrug Baikonur  \
# 0                             89       94
# 1                           None     None
# 2                           None     None
# 3                           None     None
# 4                           None     None
# 5                           None     None
# 6                           None     None
# 7                           None     None
# 8                           None     None
# 9                           None     None
#
#   Occupational Administration of Kharkiv Oblast
# 0                                           188
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                          None
# 7                                          None
# 8                                          None
# 9                                          None
#
# [10 rows x 91 columns]

# %%
region_codes_df = region_codes_df.melt(var_name='region', value_name='region_code').dropna().reset_index(drop=True)
region_codes_df
# Out:
#                                             region region_code
# 0                               Republic of Adygea          01
# 1                                   Altai Republic          04
# 2                        Republic of Bashkortostan          02
# 3                        Republic of Bashkortostan         102
# 4                        Republic of Bashkortostan         702
# ..                                             ...         ...
# 155                  Khanty-Mansi Autonomous Okrug         186
# 156                      Chukotka Autonomous Okrug          87
# 157                 Yamalo-Nenets Autonomous Okrug          89
# 158                                       Baikonur          94
# 159  Occupational Administration of Kharkiv Oblast         188
#
# [160 rows x 2 columns]

# %%
region_codes_df['region_code'] = region_codes_df['region_code'].astype(str)

# %%
region_codes_df.head(5)
# Out:
#                       region region_code
# 0         Republic of Adygea          01
# 1             Altai Republic          04
# 2  Republic of Bashkortostan          02
# 3  Republic of Bashkortostan         102
# 4  Republic of Bashkortostan         702

# %%
region_codes_df.dtypes
# Out:
# region         object
# region_code    object
# dtype: object

# %%
records = []

for (letters, (num_from, num_to), region), (description, is_forbidden, road_advantage, significance) in GOVERNMENT_CODES.items():
    records.append({
        "letters": letters,
        "number_from": num_from,
        "number_to": num_to,
        "region": region,
        "description": description,
        "is_forbidden": is_forbidden,
        "road_advantage": road_advantage,
        "significance": significance
    })

# %%
records
# Out:
# [{'letters': 'AMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '97',
#   'description': 'Government of Russia',
#   'is_forbidden': 1,
#   'road_advantage': 1,
#   'significance': 10},
#  {'letters': 'AMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 8},
#  {'letters': 'EKX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Federal Protective Service (Federal Protective Service)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'EKX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '97',
#   'description': 'Partially Federal Protective Service (Federal Protective Service)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'EKX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '99',
#   'description': 'Partially Federal Protective Service (Federal Protective Service)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'KKX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially used on vehicles of Ministry of Security/Federal Counterintelligence Service /Federal Security Service of Russia',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'CAC',
#   'number_from': 500,
#   'number_to': 999,
#   'region': '77',
#   'description': "Former officially 'open' plates of Ministry of Security/Federal Counterintelligence Service /Federal Security Service of Russia",
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'AOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Presidential Administrative Directorate plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'BOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Presidential Administrative Directorate plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'MOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Presidential Administrative Directorate plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'COO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Administrative Directorate, Federation Council plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'AMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '99',
#   'description': 'Partially plates of Moscow City Duma deputies, police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Central Special Communication, Courier Service, Ministry of Communications',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '99',
#   'description': 'Partially Tax Police, Customs, Special Communications',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '97',
#   'description': 'Partially Central Special Communication, Courier Service, Ministry of Communications',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'KKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '99',
#   'description': 'Initially belonged to Courier Service, now used among private individuals',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Initially intended for Federal Security Service',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'KMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Fire Department plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MMP',
#   'number_from': 300,
#   'number_to': 320,
#   'region': '77',
#   'description': 'Partially Federal Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'MMP',
#   'number_from': 0,
#   'number_to': 299,
#   'region': '77',
#   'description': 'Partially Government of Russia, Federal Security Service, banks, and private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'MMP',
#   'number_from': 321,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia, Federal Security Service, banks, and private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'PMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Ministry of Justice plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Moscow City Hall plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Constitutional Court plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'EPE',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially State Duma plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Administration of the President plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'KMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'TMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia plates, as well as private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'YMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia plates, as well as private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'XXX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'YYY',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'XKX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Federal Security Service and Federal Protective Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'OMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Partially Government of Russia, banks, and private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'EEE',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '77',
#   'description': 'Private individuals with connections in the traffic police',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'AMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'BMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'KMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'TMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'HMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'YMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'XMO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially various government agencies (administration, ambulance, traffic police, etc.)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': 'Partially plates of the regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '90',
#   'description': 'Partially plates of the regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '50',
#   'description': "Partially plates of law enforcement in the region (prosecutor's office, EMERCOM, traffic police, etc.)",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '90',
#   'description': "Partially plates of law enforcement in the region (prosecutor's office, EMERCOM, traffic police, etc.)",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OBO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially Departmental Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'OBO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially Departmental Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'OTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially former traffic police plates (now replaced by 98)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially traffic police plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'OMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially city district police plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially city district police plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially plates of the Main Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially plates of the Main Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OKO',
#   'number_from': 0,
#   'number_to': 100,
#   'region': '78',
#   'description': "Partially former plates of the prosecutor's office and judicial department (now replaced by 98)",
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OKO',
#   'number_from': 0,
#   'number_to': 100,
#   'region': '98',
#   'description': "Partially plates of the prosecutor's office and judicial department",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OKO',
#   'number_from': 700,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially former Federal Security Service plates (now replaced by 98)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OKO',
#   'number_from': 700,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially Federal Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially former plates of the Main Department of Internal Affairs (now replaced by 98)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially plates of the Main Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially Federal Drug Control Service and Federal Tax Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially Federal Drug Control Service and Federal Tax Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OAO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially plates of the city and regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OAO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially plates of the city and regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 100,
#   'region': '78',
#   'description': 'Partially plates of the city and regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 100,
#   'region': '98',
#   'description': 'Partially plates of the city and regional administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 6},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 899,
#   'region': '78',
#   'description': 'Commercial plates',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 899,
#   'region': '98',
#   'description': 'Commercial plates',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'OOO',
#   'number_from': 900,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially Federal Protective Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOO',
#   'number_from': 900,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially Federal Protective Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OKC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially Constitutional Court of the Russian Federation plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Partially plates of heads of enterprises and organizations',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'OOC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Partially plates of heads of enterprises and organizations',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '78',
#   'description': 'Commercial plates',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '98',
#   'description': 'Commercial plates',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'XXX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Widespread 'special' plates",
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Rare 'special' plates",
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Partially prosecutor's office of the republic",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'PPA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Partially prosecutor's office of the republic",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MPA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': 'Partially Ministry of Internal Affairs of the republic',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': 'Partially plates of the government of the republic',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Partially the republic's tax service plates",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '04',
#   'description': "Partially plates belonging to the republic's judges",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'PKC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '02',
#   'description': 'Partially State Assembly (Kurultai) plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KKC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '02',
#   'description': 'Partially State Assembly (Kurultai) plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '02',
#   'description': 'Partially plates of leaders of large enterprises and ministries',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '02',
#   'description': "Partially plates of the republic's government",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '10',
#   'description': 'Partially government of the republic and Federal Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '10',
#   'description': 'Partially plates of city and district administrations of the republic',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '10',
#   'description': 'Partially plates of the Ministry of Internal Affairs of the republic',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'EMP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '10',
#   'description': 'Partially plates of the Ministry of Internal Affairs of the republic',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '10',
#   'description': "Partially plates of the prosecutor's office and judges' vehicles",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '11',
#   'description': 'Partially government of the republic and Federal Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '11',
#   'description': 'Widespread semi-special plates, leaders of large industrial companies',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '14',
#   'description': "Partially plates of the republic's prosecutor's office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '14',
#   'description': 'Motor pool of the President, Government, Parliament of the republic, as well as heads of state enterprises',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '16',
#   'description': 'Partially plates of heads of district administrations',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '116',
#   'description': 'Partially plates of heads of district administrations',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '716',
#   'description': 'Partially plates of heads of district administrations',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '23',
#   'description': 'Partially plates of the Krai and city administrations',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '23',
#   'description': 'Partially plates of the tax authorities',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '23',
#   'description': 'Partially plates of the Krai and city administrations',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '23',
#   'description': 'Partially plates of the Krai administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KPK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '24',
#   'description': 'Partially plates of the Krai administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '24',
#   'description': 'Partially Federal Security Service plates of the Krai',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '24',
#   'description': 'Partially former plates of the Ministry of Internal Affairs of the Krai',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'BOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially military plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'BOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially city services plates in Vladivostok and districts',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Issued first in Vladivostok',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 2},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': "One of the most 'special' series, prosecutor's office",
#   'is_forbidden': 1,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the administration and vehicles of City Duma deputies',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the deputies of the Krai Legislative Assembly',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CCC',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the Krai administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'XXX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': "Partially plates of the prosecutor's office and the Department of Internal Affairs",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially former plates of the Krai administration (during Governor Evgeny Nazdratenko)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially former plates of the Vladivostok administration and federal agencies in the Krai (during Mayor Yuri Kopylov)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'MBK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates for employees of the Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MBK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially plates for employees of the Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates for Krai agencies of the Department of Internal Affairs, EMERCOM, firefighters, etc.',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'MOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially plates for Krai agencies of the Department of Internal Affairs, EMERCOM, firefighters, etc.',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'HOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the southeastern region of the Krai (Nakhodka)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'HOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the southeastern region of the Krai (Nakhodka)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'YOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the central region of the Krai (Ussuriysk)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'YOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the central region of the Krai (Ussuriysk)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'COO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '25',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the northern region of the Krai (Spassk-Dalny)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'COO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '125',
#   'description': 'Partially plates of the Department of Internal Affairs, traffic police in the northern region of the Krai (Spassk-Dalny)',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '35',
#   'description': 'Partially plates of the regional government and Vologda city administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AAM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': 'Partially plates of the Oblast Duma',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'PAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'ACK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': 'Partially plates of the Investigative Committee, Main Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'YYY',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': 'Partially Federal Security Service plates',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '34',
#   'description': 'Partially plates of the Federal Bailiff Service, Ministry of Justice, and Judicial Department',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'ААА',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '36',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'BOA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '36',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '36',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '39',
#   'description': "Partially plates of the Oblast Administration, Federal Security Service, and Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '39',
#   'description': "Partially plates of the Oblast Administration, Federal Security Service, and Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '39',
#   'description': 'Partially former plates of the Oblast Administration (during Governor Boos)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '40',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '40',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '40',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '45',
#   'description': 'Partially former plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '45',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OKO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '45',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 199,
#   'region': '54',
#   'description': 'Plates for Presidential Plenipotentiaries',
#   'is_forbidden': 1,
#   'road_advantage': 1,
#   'significance': 7},
#  {'letters': 'AAA',
#   'number_from': 200,
#   'number_to': 999,
#   'region': '54',
#   'description': "'Special' plates",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': "Partially plates of the Novosibirsk mayor's office, Oblast Administration, and Oblast Council",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'ACK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': 'Partially Federal Security Service plates of the Oblast',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'AHO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': 'Partially former plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'AAO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': 'Partially plates of various government agencies, including district administrations of Novosibirsk',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': "'Morozov' plates (introduced by former head of traffic police Pyotr Morozov)",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'MOP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '54',
#   'description': "'Morozov' plates (introduced by former head of traffic police Pyotr Morozov)",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '57',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '57',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'OAO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '57',
#   'description': 'Partially plates of directors of public joint-stock companies',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 2},
#  {'letters': 'APO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of district heads of Rostov-on-Don, mayors of Oblast cities',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'APY',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of the Rostov-on-Don administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'KKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially former plates for Presidential Plenipotentiaries (during Viktor Kazantsev)',
#   'is_forbidden': 0,
#   'road_advantage': 0,
#   'significance': 1},
#  {'letters': 'HHH',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of the Oblast Department of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OOO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of the Oblast Legislative Assembly',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 4},
#  {'letters': 'BBK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '61',
#   'description': 'Partially plates of insurance companies in Rostov-on-Don',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 1},
#  {'letters': 'AAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '164',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '164',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'XXX',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '64',
#   'description': 'Partially plates of the Oblast courts',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'MMM',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '64',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'OAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '64',
#   'description': 'Partially Federal Security Service plates of the Oblast',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'ATO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '70',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'ATO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PTO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'MTO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': "Partially plates of the Oblast Prosecutor's Office",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'HTO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the Tax Service',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'CTO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the Oblast courts',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'YTO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the bailiff service',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'BAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': 'Partially plates of the Oblast Ministry of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'KKK',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '72',
#   'description': "'Gangster' plates",
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 1},
#  {'letters': 'TTT',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '29',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PPP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '29',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'MAO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '29',
#   'description': 'Partially plates of the Oblast Ministry of Internal Affairs',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 3},
#  {'letters': 'APO',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '62',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'PAA',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '63',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5},
#  {'letters': 'AAP',
#   'number_from': 0,
#   'number_to': 999,
#   'region': '63',
#   'description': 'Partially plates of the Oblast Administration',
#   'is_forbidden': 0,
#   'road_advantage': 1,
#   'significance': 5}]

# %%
government_codes_df = pd.DataFrame(records)
government_codes_df.head()
# Out:
#   letters  number_from  number_to region  \
# 0     AMP            0        999     97
# 1     AMP            0        999     77
# 2     EKX            0        999     77
# 3     EKX            0        999     97
# 4     EKX            0        999     99
#
#                                          description  is_forbidden  \
# 0                               Government of Russia             1
# 1                     Partially Government of Russia             0
# 2  Partially Federal Protective Service (Federal ...             0
# 3  Partially Federal Protective Service (Federal ...             0
# 4  Partially Federal Protective Service (Federal ...             0
#
#    road_advantage  significance
# 0               1            10
# 1               1             8
# 2               1             6
# 3               1             6
# 4               1             6

# %%
import re

def parse_plate(plate):
    match = re.match(r'([A-Z])(\d{3})([A-Z]{2})(\d{2,3})$', plate)
    if match:
        return match.groups()  # letters1, number, letters2, region_code
    return None, None, None, None

# %%
train[['letter1', 'number', 'letter2', 'region_code']] = (train['plate'].apply(lambda p: pd.Series(parse_plate(p))))

# %%
test[['letter1', 'number', 'letter2', 'region_code']] = (test['plate'].apply(lambda p: pd.Series(parse_plate(p))))

# %%
train.head()
# Out:
#    id      plate                 date   price letter1 number letter2  \
# 0   1  X059CP797  2024-12-26 00:00:00   65000       X    059      CP
# 1   2  Y800MH790  2024-07-12 21:31:37  100000       Y    800      MH
# 2   3   A212TX77  2024-04-18 00:00:00  290000       A    212      TX
# 3   4  P001AY199  2025-01-03 00:27:15  680000       P    001      AY
# 4   5  P001AY199  2025-01-10 09:32:41  750000       P    001      AY
#
#   region_code
# 0         797
# 1         790
# 2          77
# 3         199
# 4         199

# %%
test.head()
# Out:
#       id      plate                 date  price letter1 number letter2  \
# 0  51636  P700TT790  2025-01-27 00:00:00    NaN       P    700      TT
# 1  51637  M081TX797  2025-02-10 00:00:00    NaN       M    081      TX
# 2  51638  T333HX777  2025-02-11 00:00:00    NaN       T    333      HX
# 3  51639  H744BH977  2025-02-03 00:00:00    NaN       H    744      BH
# 4  51640  X066EM777  2025-02-12 00:00:00    NaN       X    066      EM
#
#   region_code
# 0         790
# 1         797
# 2         777
# 3         977
# 4         777

# %%
train['plate_letters'] = train['letter1'] + train['letter2']

# %%
train['plate_number'] = pd.to_numeric(train['number'], errors='coerce')

# %%
train['region_code'] = train['region_code'].astype(str)

# %%
government_codes_df['region'] = government_codes_df['region'].astype(str)

# %%
merged = train.merge(government_codes_df, left_on=['plate_letters', 'region_code'], right_on=['letters', 'region'],
    how='left', suffixes=('', '_gov'))

# %%
merged['is_government'] = ((merged['plate_number'] >= merged['number_from']) & (merged['plate_number'] <= merged['number_to']))

# %%
merged['is_government'] = merged['is_government'].fillna(False)

# %%
train['is_government'] = merged['is_government']
train = train.drop(['letter1', 'letter2', 'number'], axis=1)
train.head()
# Out:
#    id      plate                 date   price region_code plate_letters  \
# 0   1  X059CP797  2024-12-26 00:00:00   65000         797           XCP
# 1   2  Y800MH790  2024-07-12 21:31:37  100000         790           YMH
# 2   3   A212TX77  2024-04-18 00:00:00  290000          77           ATX
# 3   4  P001AY199  2025-01-03 00:27:15  680000         199           PAY
# 4   5  P001AY199  2025-01-10 09:32:41  750000         199           PAY
#
#    plate_number  is_government
# 0            59          False
# 1           800          False
# 2           212          False
# 3             1          False
# 4             1          False

# %%
test['plate_letters'] = test['letter1'] + test['letter2']

# %%
test['plate_number'] = pd.to_numeric(test['number'], errors='coerce')

# %%
test['region_code'] = test['region_code'].astype(str)

# %%
government_codes_df['region'] = government_codes_df['region'].astype(str)

# %%
merged = test.merge(government_codes_df, left_on=['plate_letters', 'region_code'], right_on=['letters', 'region'], how='left',
    suffixes=('', '_gov'))

# %%
merged['is_government'] = ((merged['plate_number'] >= merged['number_from']) & (merged['plate_number'] <= merged['number_to']))

# %%
merged['is_government'] = merged['is_government'].fillna(False)

# %%
test['is_government'] = merged['is_government']
test = test.drop(['letter1', 'letter2', 'number'], axis=1)

# %%
train = train.merge(region_codes_df, on='region_code', how='left')
test = test.merge(region_codes_df, on='region_code', how='left')

# %%
train.head()
# Out:
#    id      plate                 date   price region_code plate_letters  \
# 0   1  X059CP797  2024-12-26 00:00:00   65000         797           XCP
# 1   2  Y800MH790  2024-07-12 21:31:37  100000         790           YMH
# 2   3   A212TX77  2024-04-18 00:00:00  290000          77           ATX
# 3   4  P001AY199  2025-01-03 00:27:15  680000         199           PAY
# 4   5  P001AY199  2025-01-10 09:32:41  750000         199           PAY
#
#    plate_number  is_government         region
# 0            59          False         Moscow
# 1           800          False  Moscow Oblast
# 2           212          False         Moscow
# 3             1          False         Moscow
# 4             1          False         Moscow

# %%
test.head()
# Out:
#       id      plate                 date  price region_code plate_letters  \
# 0  51636  P700TT790  2025-01-27 00:00:00    NaN         790           PTT
# 1  51637  M081TX797  2025-02-10 00:00:00    NaN         797           MTX
# 2  51638  T333HX777  2025-02-11 00:00:00    NaN         777           THX
# 3  51639  H744BH977  2025-02-03 00:00:00    NaN         977           HBH
# 4  51640  X066EM777  2025-02-12 00:00:00    NaN         777           XEM
#
#    plate_number  is_government         region
# 0           700          False  Moscow Oblast
# 1            81          False         Moscow
# 2           333          False         Moscow
# 3           744          False         Moscow
# 4            66          False         Moscow

# %%
cols = ['plate_letters', 'is_government', 'region']

for col in cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

# %%
all_plates = pd.concat([train['plate'], test['plate']]).astype(str)
all_plates
# Out:
# 0       X059CP797
# 1       Y800MH790
# 2        A212TX77
# 3       P001AY199
# 4       P001AY199
#           ...
# 7690    X799CC799
# 7691    K077YT777
# 7692    O200PA777
# 7693     O073OO97
# 7694    A666YE790
# Name: plate, Length: 59335, dtype: object

# %%
le = LabelEncoder()
le.fit(all_plates)
train['plate'] = le.transform(train['plate'].astype(str))
test['plate'] = le.transform(test['plate'].astype(str))

# %%
def date_change(df):
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df = df.drop(['date'], axis=1)
    return df

# %%
train = date_change(train)
test = date_change(test)

# %%
train['region_code'] = train['region_code'].astype('int64')
test['region_code'] = test['region_code'].astype('int64')

# %%
train.head()
# Out:
#    id  plate   price  region_code  plate_letters  plate_number  is_government  \
# 0   1  44645   65000          797           1472            59              0
# 1   2  50771  100000          790           1660           800              0
# 2   3   2152  290000           77            118           212              0
# 3   4  36260  680000          199           1163             1              0
# 4   5  36260  750000          199           1163             1              0
#
#    region  year  month
# 0      35  2024     12
# 1      36  2024      7
# 2      35  2024      4
# 3      35  2025      1
# 4      35  2025      1

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    diff = np.abs(y_true - y_pred)
    smape_val = np.where(denominator == 0, 0, diff / denominator)
    return np.mean(smape_val) * 100
smape_scorer = make_scorer(smape, greater_is_better=False)

# %%
test_ids = test['id']
y = train['price']
X = train[['plate', 'region_code', 'plate_letters', 'plate_number', 'is_government', 'region', 'year', 'month']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (41312, 41312, 10328, 10328)

# %%
correlation = X.assign(target=y).corr()['target'].drop('target')
print(correlation.sort_values(ascending=False))
# Out:
# year             0.046109
# plate_number     0.025181
# is_government    0.011925
# region          -0.004331
# month           -0.006424
# plate           -0.033682
# plate_letters   -0.034453
# region_code     -0.115595
# Name: target, dtype: float64

# %%
model = XGBRegressor(colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=6, n_estimators=1500, reg_alpha=0, reg_lambda=2, subsample=0.8)
model.fit(X_train, y_train, verbose=False)
pred = model.predict(X_test)
smape(y_test, pred)
# Out:
# 62.876972203533285

# %%
test_sub = test[['plate', 'region_code', 'plate_letters', 'plate_number', 'is_government', 'region', 'year', 'month']]

# %%
submission_predictions = model.predict(test_sub)

# %%
submission = pd.DataFrame({'id': test_ids.values, 'price': submission_predictions})
submission.head(5)
# Out:
#       id          price
# 0  51636   68651.117188
# 1  51637  100743.062500
# 2  51638  496677.656250
# 3  51639   69703.835938
# 4  51640  479860.156250

# %%
submission.to_csv('Solution.csv', index = False)
