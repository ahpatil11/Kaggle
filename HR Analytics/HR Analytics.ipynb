# %% [raw]
# Project Objectives
#
# 1) Which are the significant variables to describe the dataset
# 2) who are the employees that have left
# 3) Focus the analysis on the most valuable employees who have left
# 4) Devolop a predictive model to assess the likelihood of an employee leaving

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HR_comma_sep.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [raw]
# There are no null values

# %% [raw]
# Univariate Analysis

# %%
df.Work_accident.value_counts().plot(kind='bar')

# %%
no_work_accident = len(df[df['Work_accident']==0])
work_accident = len(df[df['Work_accident']==1])
print(no_work_accident/len(df.Work_accident)*100)
# Out:
# 85.53903593572905

# %% [raw]
# Around 85.53% has no accident while rest has work accident

# %%
df.left.value_counts().plot(kind='bar')

# %%
employee_left = len(df[df['left']==1])
print(employee_left/len(df['left'])*100)
# Out:
# 23.80825388359224

# %% [raw]
# so 23.80% employee left

# %%
df.promotion_last_5years.value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
promotion_not_done = len(df[df['promotion_last_5years']==0])
print(promotion_not_done/len(df['promotion_last_5years'])*100)
# Out:
# 97.87319154610307

# %% [raw]
# 97.87% of the employee promotion did not took place

# %%
df.sales.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %% [raw]
# Highest employees are in the sales department

# %%
df.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
low1 = len(df[df['salary']=='low'])
medium1 = len(df[df['salary']=='medium'])
high1 = len(df[df['salary']=='high'])
print("low salary % is ", low1/len(df['salary'])*100)
print("Medium salary % is ", medium1/len(df['salary'])*100)
print("High salary % is ", high1/len(df['salary'])*100)
# Out:
# low salary % is  48.77658510567372
# Medium salary % is  42.97619841322755
# High salary % is  8.24721648109874

# %% [raw]
# Bivariate Analysis

# %% [raw]
# We will check how many employees get the low, high and medium salary on the basis of their department

# %%
pd.crosstab(df['salary'], df['sales'])
# Out:
# sales    IT  RandD  accounting   hr  management  marketing  product_mng  \
# salary
# high     83     51          74   45         225         80           68
# low     609    364         358  335         180        402          451
# medium  535    372         335  359         225        376          383
#
# sales   sales  support  technical
# salary
# high      269      141        201
# low      2099     1146       1372
# medium   1772      942       1147

# %%
sns.barplot(df['salary'], df['satisfaction_level'])

# %%
df.groupby('salary').mean().sort_values(by = 'satisfaction_level', ascending = False)['satisfaction_level']
# Out:
# salary
# high      0.637470
# medium    0.621817
# low       0.600753
# Name: satisfaction_level, dtype: float64

# %%
fig = plt.figure(figsize =(15,5))
sns.barplot(df['sales'], df['satisfaction_level'])

# %%
df.groupby('sales').mean().sort_values(by= 'satisfaction_level',ascending = False)['satisfaction_level']
# Out:
# sales
# management     0.621349
# RandD          0.619822
# product_mng    0.619634
# marketing      0.618601
# support        0.618300
# IT             0.618142
# sales          0.614447
# technical      0.607897
# hr             0.598809
# accounting     0.582151
# Name: satisfaction_level, dtype: float64

# %% [raw]
# Management has the highest satisfaction level

# %%
sns.barplot(df['salary'], df['left'])

# %% [raw]
# Employee with less salary is likely to leave

# %%
df1 = df.copy()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1['sales'] = le.fit_transform(df1['sales'])
df1['salary'] = le.fit_transform(df1['salary'])
df1['sales'] = df1['sales'].astype(int)
df1['salary'] = df1['salary'].astype(int)
df1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0      7
# 1                   6              0     1                      0      7
# 2                   4              0     1                      0      7
# 3                   5              0     1                      0      7
# 4                   3              0     1                      0      7
#
#    salary
# 0       1
# 1       2
# 2       2
# 3       1
# ...

# %%
a = df1[df1['left'] == 1]

# %%
a.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0      7
# 1                   6              0     1                      0      7
# 2                   4              0     1                      0      7
# 3                   5              0     1                      0      7
# 4                   3              0     1                      0      7
#
#    salary
# 0       1
# 1       2
# 2       2
# 3       1
# ...

# %%
a.time_spend_company.value_counts()
# Out:
# 3    1586
# 4     890
# 5     833
# 6     209
# 2      53
# Name: time_spend_company, dtype: int64

# %% [raw]
# Therefore msotly employees having mid level experience i.e time spend in the company for 2 to 6 years has left the organisation

# %%
a.groupby('time_spend_company').mean()['satisfaction_level']
# Out:
# time_spend_company
# 2    0.521698
# 3    0.411740
# 4    0.146933
# 5    0.714034
# 6    0.791196
# Name: satisfaction_level, dtype: float64

# %%
a.groupby('time_spend_company').mean()['number_project']
# Out:
# time_spend_company
# 2    4.056604
# 3    2.097730
# 4    5.960674
# 5    4.759904
# 6    4.574163
# Name: number_project, dtype: float64

# %%
print(a.corr(method='pearson')['satisfaction_level'][1:].sort_values(ascending=False))
# Out:
# time_spend_company       0.446440
# last_evaluation          0.182295
# sales                    0.033990
# Work_accident            0.005864
# promotion_last_5years    0.005516
# salary                  -0.003216
# average_montly_hours    -0.084117
# number_project          -0.227113
# left                          NaN
# Name: satisfaction_level, dtype: float64

# %% [raw]
# Employee who work in organization for 4 years has been given more number of projects. Thus
# Time spent at the company and the number of projects worked on, have the greatest impact.
# Employee’s average monthly hours and their last evaluation also have significant impact

# %%
b = df1[df1['left'] == 0]

# %%
left_satisfaction = a['satisfaction_level'].mean()
stay_satisfaction = b['satisfaction_level'].mean()
print(left_satisfaction)
print(stay_satisfaction)
# Out:
# 0.44009801176140917
# 0.666809590479516

# %%
fig = plt.figure(figsize = (12,5))
a.sales.value_counts().plot(kind = 'bar')

# %% [raw]
# Sales department employees have recorded the highest for leaving an organisation.
# Management department employees has been recorded the least for leaving an organisation due to its high satisfaction level.

# %%
fig = plt.figure(figsize=(12,5))
sns.heatmap(df1.corr(), annot = True)

# %% [raw]
# Hence due to satisfaction level, work accident and salary, employees have left

# %%
x = df1.drop('left',axis = 1)
y = df1['left']
from sklearn.feature_selection import SelectKBest, chi2
bestFeatures = SelectKBest(score_func= chi2, k = 5)
fit = bestFeatures.fit(x, y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

featureScores = pd.concat([dfcolumns, dfscores], axis = 1)
featureScores.columns = ['Specs','Score']

featureScores.nlargest(5, 'Score')
# Out:
#                    Specs       Score
# 3   average_montly_hours  945.588933
# 5          Work_accident  306.737710
# 0     satisfaction_level  228.193183
# 4     time_spend_company  191.708547
# 6  promotion_last_5years   56.044865

# %% [raw]
# Building our model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(x_train, y_train)
# Out:
# C:\Users\Akshay\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lor.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score, accuracy_score

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2116  171]
#  [ 520  193]]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7696666666666667

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      2287
#            1       0.53      0.27      0.36       713
#
#     accuracy                           0.77      3000
#    macro avg       0.67      0.60      0.61      3000
# weighted avg       0.74      0.77      0.74      3000

# %%
print(cohen_kappa_score(y_test, y_pred))
# Out:
# 0.23560143012224477

# %%
def decision_tree():
    from sklearn import tree
    from sklearn.model_selection import GridSearchCV, cross_val_score
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    from sklearn.pipeline import Pipeline

    decisiontree = tree.DecisionTreeClassifier()

    pipe = Pipeline(steps=[('sc', sc),
                           ('decisiontree', decisiontree)])

    n_components = list(range(1,7))

    criterion = ['gini', 'entropy']
    max_depth = [1,2,3,4,5]

    parameters = dict(decisiontree__criterion=criterion,
                      decisiontree__max_depth=max_depth)

    clf = GridSearchCV(pipe, parameters)

    clf.fit(x_train, y_train)

    print('Best Criterion:', clf.best_estimator_.get_params()['decisiontree__criterion'])
    print('Best max_depth:', clf.best_estimator_.get_params()['decisiontree__max_depth'])
    print(clf.best_estimator_.get_params()['decisiontree'])



decision_tree()
# Out:
# C:\Users\Akshay\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Best Criterion: gini
# Best max_depth: 5
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='gini', max_depth=5)
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_pred = dtree.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred))

accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))

print(cohen_kappa_score(y_test, y_pred))
# Out:
# [[2264   23]
#  [  53  660]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2287
#            1       0.97      0.93      0.95       713
#
#     accuracy                           0.97      3000
#    macro avg       0.97      0.96      0.96      3000
# weighted avg       0.97      0.97      0.97      3000
#
# 0.9290612879358764

# %%
dtree.score(x_train, y_train)
# Out:
# 0.9754146178848238

# %%
dtree.score(x_test, y_test)
# Out:
# 0.9746666666666667

# %%
y_pred = dtree.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(x)
features

dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
# Out:
# C:\Users\Akshay\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [raw]
# Conclusions -
# 1) Average monthly hours, satisfaction level, time spend company and promotion last 5years are significant variable
# 2) Sales department employees have recorded the highest for leaving an organisation.
# Therefore mostly employees having mid level experience has left the organisation due to average monthly hours, last_evaluation
# and number of projects and satisfaction
# 3) Managing level of satisfaction is priority to keep employee in the organization and it is important for mid level
# experience
