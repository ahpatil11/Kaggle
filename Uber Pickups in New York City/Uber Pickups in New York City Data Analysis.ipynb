# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
apr = pd.read_csv('uber-raw-data-apr14.csv')
may = pd.read_csv('uber-raw-data-may14.csv')
jun = pd.read_csv('uber-raw-data-jun14.csv')
jul = pd.read_csv('uber-raw-data-jul14.csv')
aug = pd.read_csv('uber-raw-data-aug14.csv')
sep = pd.read_csv('uber-raw-data-sep14.csv')

# %%
apr['Date/Time'] = pd.to_datetime(apr['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
apr.head()
# Out:
#             Date/Time      Lat      Lon    Base
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512

# %%
apr['DayOfWeek'] = apr['Date/Time'].dt.weekday_name
apr['Day'] = apr['Date/Time'].dt.day
apr['Hour'] = apr['Date/Time'].dt.hour

# %%
apr.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512   Tuesday    1     0
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512   Tuesday    1     0
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512   Tuesday    1     0
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512   Tuesday    1     0
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512   Tuesday    1     0

# %%
may['Date/Time'] = pd.to_datetime(may['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
may['DayOfWeek'] = may['Date/Time'].dt.weekday_name
may['Day'] = may['Date/Time'].dt.day
may['Hour'] = may['Date/Time'].dt.hour
may.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  Thursday    1     0
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  Thursday    1     0
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  Thursday    1     0
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  Thursday    1     0
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  Thursday    1     0

# %%
jun['Date/Time'] = pd.to_datetime(jun['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
jun['DayOfWeek'] = jun['Date/Time'].dt.weekday_name
jun['Day'] = jun['Date/Time'].dt.day
jun['Hour'] = jun['Date/Time'].dt.hour
jun.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-06-01 00:00:00  40.7293 -73.9920  B02512    Sunday    1     0
# 1 2014-06-01 00:01:00  40.7131 -74.0097  B02512    Sunday    1     0
# 2 2014-06-01 00:04:00  40.3461 -74.6610  B02512    Sunday    1     0
# 3 2014-06-01 00:04:00  40.7555 -73.9833  B02512    Sunday    1     0
# 4 2014-06-01 00:07:00  40.6880 -74.1831  B02512    Sunday    1     0

# %%
jul['Date/Time'] = pd.to_datetime(jul['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
jul['DayOfWeek'] = jun['Date/Time'].dt.weekday_name
jul['Day'] = jul['Date/Time'].dt.day
jul['Hour'] = jul['Date/Time'].dt.hour
jul.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-07-01 00:03:00  40.7586 -73.9706  B02512    Sunday    1     0
# 1 2014-07-01 00:05:00  40.7605 -73.9994  B02512    Sunday    1     0
# 2 2014-07-01 00:06:00  40.7320 -73.9999  B02512    Sunday    1     0
# 3 2014-07-01 00:09:00  40.7635 -73.9793  B02512    Sunday    1     0
# 4 2014-07-01 00:20:00  40.7204 -74.0047  B02512    Sunday    1     0

# %%
aug['Date/Time'] = pd.to_datetime(aug['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
aug['DayOfWeek'] = jun['Date/Time'].dt.weekday_name
aug['Day'] = aug['Date/Time'].dt.day
aug['Hour'] = aug['Date/Time'].dt.hour
aug.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-08-01 00:03:00  40.7366 -73.9906  B02512    Sunday    1     0
# 1 2014-08-01 00:09:00  40.7260 -73.9918  B02512    Sunday    1     0
# 2 2014-08-01 00:12:00  40.7209 -74.0507  B02512    Sunday    1     0
# 3 2014-08-01 00:12:00  40.7387 -73.9856  B02512    Sunday    1     0
# 4 2014-08-01 00:12:00  40.7323 -74.0077  B02512    Sunday    1     0

# %%
sep['Date/Time'] = pd.to_datetime(sep['Date/Time'], format = ('%m/%d/%Y %H:%M:%S'))
sep['DayOfWeek'] = jun['Date/Time'].dt.weekday_name
sep['Day'] = sep['Date/Time'].dt.day
sep['Hour'] = sep['Date/Time'].dt.hour
sep.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512    Sunday    1     0
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512    Sunday    1     0
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512    Sunday    1     0
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512    Sunday    1     0
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512    Sunday    1     0

# %% [raw]
# Monthly Analysis

# %%
apr_uber_weekdays_count = apr.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
apr_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
apr_Day_count = apr.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
apr_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
apr_Hour_count = apr.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
apr_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(apr_uber_weekdays_count)
ax2.plot(apr_Day_count)

# %%
may_uber_weekdays_count = may.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
may_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
may_Day_count = may.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
may_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
may_Hour_count = may.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
may_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(may_uber_weekdays_count)
ax2.plot(may_Day_count)

# %%
jun_uber_weekdays_count = jun.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
jun_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
jun_Day_count = jun.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
jun_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
jun_Hour_count = jun.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
jun_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(jun_uber_weekdays_count)
ax2.plot(jun_Day_count)

# %%
jul_uber_weekdays_count = jul.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
jul_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
jul_Day_count = jul.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
jul_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
jul_Hour_count = jul.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
jul_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(jul_uber_weekdays_count)
ax2.plot(jul_Day_count)

# %%
aug_uber_weekdays_count = aug.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
aug_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
aug_Day_count = aug.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
aug_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
aug_Hour_count = aug.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
aug_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(aug_uber_weekdays_count)
ax2.plot(aug_Day_count)

# %%
sep_uber_weekdays_count = sep.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
sep_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
sep_Day_count = sep.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')
sep_Day_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
sep_Hour_count = sep.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
sep_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Journeys')
# Out:
# Text(0, 0.5, 'Total Journeys')

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(sep_uber_weekdays_count)
ax2.plot(sep_Day_count)

# %% [raw]
# On Monthly Analysis we infer that-
# In the month of April - Evening has lots of uber ride and moreover Wednesday has witnessed large number of journeys made.
# May - In the mid may the number of journey has seen increased and day is Friday.
# June - Most of the people have booked their uber ride on the Thursday and most ride has made in the evening.
# July - Like in the month of June, people have booked their ride on Thursday and has travelled in the evening.
# Aug - People prefer Friday and most people has travelled in the evening.
# Sept - Maximum number of journey has been made in Thursday and in evenings.

# %%
df = pd.concat([apr, may, jun, jul, aug, sep])
df.head()
# Out:
#             Date/Time      Lat      Lon    Base DayOfWeek  Day  Hour
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512   Tuesday    1     0
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512   Tuesday    1     0
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512   Tuesday    1     0
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512   Tuesday    1     0
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512   Tuesday    1     0

# %%
df.shape
# Out:
# (4534327, 7)

# %%
combined_uber_weekdays_count = df.pivot_table(index = ['DayOfWeek'], values = 'Base', aggfunc = 'count')
combined_Hour_count = df.pivot_table(index= ['Hour'], values= 'Base', aggfunc = 'count')
combined_Day_count = df.pivot_table(index= ['Day'], values = 'Base', aggfunc = 'count')

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 1, 2)

ax1.plot(combined_uber_weekdays_count)
ax2.plot(combined_Hour_count)
ax3.plot(combined_Day_count)

# %% [raw]
# From combining the data from April to September -
# Most of the uber rides has been booked on Thursday and least done in Sunday.
# Evening has been most of the journey's made rather than in mornings.

# %%
jan_june = pd.read_csv('uber-raw-data-janjune-15.csv')
jan_june.head()
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID
# 0               B02617  2015-05-17 09:47:00              B02617         141
# 1               B02617  2015-05-17 09:47:00              B02617          65
# 2               B02617  2015-05-17 09:47:00              B02617         100
# 3               B02617  2015-05-17 09:47:00              B02774          80
# 4               B02617  2015-05-17 09:47:00              B02617          90

# %%
jan_june.dtypes
# Out:
# Dispatching_base_num    object
# Pickup_date             object
# Affiliated_base_num     object
# locationID               int64
# dtype: object

# %%
jan_june.shape
# Out:
# (14270479, 4)

# %%
jan_june['Pickup_date'] = pd.to_datetime(jan_june['Pickup_date'], format = ('%Y/%m/%d %H:%M:%S'))
jan_june.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90

# %%
jan_june['DayOfWeek'] = jan_june['Pickup_date'].dt.weekday_name
jan_june['Day'] = jan_june['Pickup_date'].dt.day
jan_june['Hour'] = jan_june['Pickup_date'].dt.hour
jan_june['Month'] = jan_june['Pickup_date'].dt.month
jan_june.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90
#
#   DayOfWeek  Day  Hour  Month
# 0    Sunday   17     9      5
# 1    Sunday   17     9      5
# 2    Sunday   17     9      5
# 3    Sunday   17     9      5
# 4    Sunday   17     9      5

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 1, 2)

ax1.plot(jan_june_uber_weekdays_count)
ax2.plot(jan_june_Hour_count)
ax3.plot(jan_june_Month_count)

# %%
jan_june_uber_weekdays_count = jan_june.pivot_table(index = ['DayOfWeek'], values = 'Affiliated_base_num', aggfunc = 'count')
jan_june_uber_weekdays_count.plot(kind = 'bar')
plt.ylabel('Total Uber Pickups')
# Out:
# Text(0, 0.5, 'Total Uber Pickups')

# %%
plt.figure(figsize= (45,5))
jan_june_Hour_count = jan_june.pivot_table(index= ['Hour'], values= 'Affiliated_base_num', aggfunc = 'count')
jan_june_Hour_count.plot(kind = 'bar')
plt.ylabel('Total Uber Pickups')
# Out:
# Text(0, 0.5, 'Total Uber Pickups')

# %%
jan_june_Month_count = jan_june.pivot_table(index= ['Month'], values = 'Affiliated_base_num', aggfunc = 'count')
jan_june_Month_count.plot(kind = 'bar')
plt.ylabel('Total Uber Pickups')
# Out:
# Text(0, 0.5, 'Total Uber Pickups')

# %% [raw]
# From Jan 2015 to June 2015 -
# The maximum number of uber rides was in the month of June.
# Evening shows the maximum number of rides.
# Saturday witnessed the maximum number of uber rides booked followed by Friday and Thursday. Least being on Monday.
